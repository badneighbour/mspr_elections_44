# %%
import pandas as pd

# %%
file_path = 'dares_defm_communales-brutes.csv'

data = pd.read_csv(file_path, delimiter=';')

columns_to_drop = ['Région', 'Code région', 'Type de données', 'Catégorie']
data_cleaned = data.drop(columns=columns_to_drop)

data_cleaned.to_csv('Data_Chomage_traiter.csv', index=False)
